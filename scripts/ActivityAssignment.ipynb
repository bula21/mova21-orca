from dateutil.parser import parse

UNIT_URL = "https://orca.mova21.ch/units/"
UNIT_URL_JSON = "https://orca.mova21.ch/units.json"
ACTIVTY_URL = "https://orca.mova21.ch/activities/"
ACTIVTY_URL_JSON = "https://orca.mova21.ch/activities.json?activity_filter[reset]=true&locale=de"
UNITS_FILE = "units.json"
ACTIVITIES_FILE = "activities.json"

class OrcaLoader:
  def __init__(self, headers, max_units=0):
    self.headers = headers
    self.max_units = max_units

  def fetch_activities(self):
    if os.path.exists(ACTIVITIES_FILE):
      cache_file = open(ACTIVITIES_FILE,)
      activities = json.load(cache_file)
    else:
      request = requests.get(ACTIVTY_URL_JSON, headers=self.headers)
      open(ACTIVITIES_FILE, 'w').write(request.text)
      activities = request.json()
    #  with open(ACTIVITIES_FILE, 'w') as cache_file:
    #    json.dump(activities, cache_file, ensure_ascii=False)

    return activities

  def fetch_units(self):
    units = []
    if os.path.exists(UNITS_FILE):
      cache_file = open(UNITS_FILE,)
      unit_index = json.load(cache_file)
    else:
      request = requests.get(UNIT_URL_JSON, headers=headers)
      open(UNITS_FILE, 'w').write(request.text)
      unit_index = request.json()
    count = len(unit_index)
    i = 0
    if not os.path.exists("units/"):
      os.mkdir("units/")
    for unit in unit_index:
      i += 1
      uid = unit.get("id")
      if str(uid) in no_program_units:
        continue
      cache_path = "units/" + str(uid) + ".json"
      if os.path.exists(cache_path):
        cache_file = open(cache_path,)
        unit = json.load(cache_file)
      else:
        logger.write("Fetching unit " + str(uid) + " " + str(i) + "/" + str(count))
        request = requests.get(
          UNIT_URL + str(uid) + ".json", headers=self.headers)
        unit = request.json()
        with open(cache_path, 'w') as cache_file:
          json.dump(unit, cache_file, ensure_ascii=False)

      units.append(unit)
      
      if self.max_units > 0 and len(units) >= self.max_units:
        break

    return units

  def load_transports(self):
    # read data file and skip first line
    lines = transport_csv.splitlines()
    reader = csv.reader(lines, delimiter=';')
    next(reader)

    return reader
      
  def load_locations(self):
    # read data file and skip first line
    lines = locations_csv.splitlines()
    reader = csv.reader(lines, delimiter=',')
    next(reader)

    return reader

# %% [markdown]
# # Activity

# %%
class Activity:
  def __init__(self, id, label, category, activity_executions=None, stufen=[]):
    self.id = id
    self.label = label
    self.category = category
    self.activity_executions = activity_executions
    self.stufen = stufen
    
  def __repr__(self):
    return f'A-{str(self.id)}: {self.label}' 

  def from_json(data, mova_scheduler):
    activity = Activity(
          id = data.get("id"),
          label = data.get("label_in_database").get("de"),
          category = data.get("activity_category").get("code"),
          stufen = data.get("stufen"))
    
    activity.activity_executions = list(map(lambda data: ActivityExecution.from_json(data, activity, mova_scheduler), data.get("activity_executions")))
   
    return activity

# %%
# representing activity object which units have booked, based on activity
# selected activity has further a priority
class SelectedActivity(Activity):
  def __init__(self, id, label, category, priority, activity_executions):
    super().__init__(id, label, category, activity_executions)
    self.priority = priority

  def __repr__(self):
    return str(super().__repr__()) + "  [Prio " + str(self.priority) + "]"

  def from_json(data, mova_scheduler):
    activity = mova_scheduler.activities.get(data.get("activity").get("id"))
    if activity:
      return SelectedActivity(activity.id, 
                              activity.label,
                              activity.category,
                              data.get("priority"),
                              activity.activity_executions)
    else:
      print(str(mova_scheduler.activities))

# %%
class ActivityExecution:
  def __init__(self, id, activity_id, amount_participants, starts_at, ends_at, languages, field, spot, transport, transport_ids, activity, stufen):
    self.id = id
    self.activity_id = activity_id
    self.activity = activity
    self.amount_participants = amount_participants
    self.starts_at = starts_at
    self.starts_at_datetime = parse(starts_at)
    self.ends_at = ends_at
    self.ends_at_datetime = parse(ends_at)
    self.languages = languages
    self.field = field
    self.spot = spot
    self.transport = transport
    self.transport_ids = transport_ids
    self.assigned_units = []
    self.stufen = stufen

  def from_json(data, activity, mova_scheduler):
    location = mova_scheduler.locations.get(str(data.get("field").get("id")), Location(cid=data.get("field").get("id"), text=data.get("field").get("name"), latitude=None, longitude=None))

    return ActivityExecution(
                              id = data.get("id"),
                              activity_id = activity.id,
                              activity = activity,
                              amount_participants = data.get("amount_participants"), 
                              starts_at = data.get("starts_at"), 
                              ends_at = data.get("ends_at"), 
                              languages = data.get("languages"), 
                              field = location,
                              spot = data.get("spot"), 
                              transport = data.get("transport"),
                              transport_ids = data.get("transport_ids"),
                              stufen = activity.stufen)
    
  def __repr__(self):
    return f'@{str(self.id)}: {str(self.activity)} ({self.headcount_used()}/{self.amount_participants}) {str(self.starts_at)} - {str(self.ends_at)} [{self.field.text}]'

  def assign(self, unit_activity_execution):
    self.assigned_units.append(unit_activity_execution)
         
    if self.languages == [] or self.languages is None:
      self.languages = [unit_activity_execution.unit.language]

  def has_language(self, language):
    return language in self.languages

  def headcount_free(self):
    return self.amount_participants - self.headcount_used()

  def headcount_used(self):
    return sum([uae.headcount for uae in self.assigned_units]) or 0

  def percentage_used(self):
    if self.amount_participants <= 0:
      return -1
    return self.headcount_used() / self.amount_participants
  
  def get_distance(self, location):
    if self.field:
      return self.field.calculate_distance(location)
    
    return -1

  def overlaps(self, other):
    if self.activity.id in non_overlap_activities or other.activity.id in non_overlap_activities:
      return False

    # Allow activities that end at the exact same time the other starts
    # return (self.starts_at <= other.ends_at) and (other.starts_at <= self.ends_at)

    if max(self.starts_at, other.starts_at) < min(self.ends_at, other.ends_at):
      return True 
    else:
      return min(abs(self.starts_at_datetime - other.ends_at_datetime), abs(self.ends_at_datetime - other.starts_at_datetime))


  def has_transport(self):
    # TODO: we have seen errors in the transport flag, should change to transport_ids (https://orca.mova21.ch/activities/187)
    return self.transport_ids is not None and len(self.transport_ids) > 0

  def dates(self):
    return set([self.starts_at.split("T")[0], self.ends_at.split("T")[0]])
  
  def week(self):
    middle = "2022-07-31T00:00:00+2000"

    if self.starts_at < middle:
      return 1
    else:
      return 2

# %% [markdown]
# # UnitActivityExecution

# %%
class UnitActivityExecution:
  def __init__(self, unit_id=None, activity_execution_id=None, activity_id=None, headcount=None, activity_execution=None, unit=None, phase=None, score=None):
    self.activity_execution_id = activity_execution_id
    self.activity_id = activity_id
    self.headcount = headcount
    self.unit = unit
    self.unit_id = unit_id
    self.activity_execution = activity_execution
    self.phase = phase
    self.score = score or 0

    if activity_execution is not None:
      self.activity_execution_id =  activity_execution.id 
      self.activity_id = activity_execution.activity_id

    if unit is not None: 
      self.unit_id = unit.id
      if headcount is None: 
        self.headcount = unit.participant_count or 0
        if activity_execution is not None and (activity_execution.has_transport() or activity_execution.activity.category in ['hiking', 'excursion', 'culture']):
          self.headcount += unit.leader_count or 0

  def __repr__(self):
    if self.activity_execution is not None:
      activity = self.activity_execution.activity
    else:
      activity = '?'
    return f'{self.unit_id}{self.activity_execution} 👤{self.headcount} [❤️{self.score}]'

  def from_json(data):
      return UnitActivityExecution(
                              data.get("unit_id"), 
                              data.get("activity_execution_id"),
                              data.get("activity_id"),
                              data.get("headcount"),
                              phase="predefined")
      
  def assign(self):
    if self.unit is not None:
      self.unit.assign(self)
    if self.activity_execution is not None:
      self.activity_execution.assign(self)

# %% [markdown]
# # Location & Transport

# %%
class Location: 
  def __init__(self, cid, text, latitude, longitude):
    self.cid = str(cid)
    self.text = text
    try: 
      self.id = int(cid)
    except Exception:
      self.id = 0

    # CH1903+
    self.latitude = float(latitude) if latitude else None
    self.longitude = float(longitude) if longitude else None
    self.distance_cache = {}

  def from_data(row):
    return Location(cid = row[0], text=row[1], latitude=row[2], longitude=row[3])

  def __repr__(self):
    return str(self.cid) + " " + str(self.latitude) + " " + str(self.longitude)

  def calculate_distance(self, location_b, force=False):
    if location_b.cid not in self.distance_cache or force == True:
      # only calcualte if we have coordinates on both
      if self.latitude and self.longitude and location_b.latitude and self.latitude:
        # some nice pythagoras
        self.distance_cache[location_b.cid] = ((self.latitude - location_b.latitude)**2 + (self.longitude - location_b.longitude)**2)**(1/2)
      else:
        self.distance_cache[location_b.cid] = None

    return self.distance_cache[location_b.cid]

# %%
class Transport: 
  def __init__(self, id, capacity):
    self.id = id
    self.capacity = int(float(capacity))

    self.assigned_units = []

  def from_data(row):
    return Transport(id = row[0], capacity=row[1])

  def get_current_degree_of_capacity(self):
    return sum([unit.size() for unit in self.assigned_units]) or 0

  def is_unit_assignable(self, unit):
    logger.write("      Debug# Unit:" + str(unit.id) + " Unit_size: " + str(unit.size()) + " Transport_Id_ " + str(self.id) + " Transport_TotalCapacity: " + str(self.capacity) + " Transport_AlreadyAssignedCapacity: " + str(self.get_current_degree_of_capacity()))
    return unit.size() <= (self.capacity - self.get_current_degree_of_capacity())

  def assign_unit(self, unit):
    self.assigned_units.append(unit)

# %% [markdown]
# # Unit

# %%
class Unit:
  def __init__(self, id, district, starts_at, ends_at, language, participant_count, leader_count, stufe, week, expected_participant_counts, abteilung):
    self.id = id
    self.district = district
    self.starts_at = starts_at
    self.ends_at = ends_at
    self.language = language
    self.participant_count = participant_count
    self.expected_participant_counts = expected_participant_counts
    self.leader_count = leader_count
    self.stufe = stufe
    self.week = week
    self.selected_activities = {}
    self.assigned_activities = []
    self.abteilung = abteilung
    self.assigned_fields = []

    if week in ["Erste Lagerwoche", "Première semaine de camp", "Prima settimana di conservazione"] or id == 1012:
      self.starts_at = "2022-07-25T00:00:00+0200"
      self.ends_at = "2022-07-29T00:00:00+0200"

    elif week in ["Zweite Lagerwoche", "Deuxième semaine de camp"]:
      self.starts_at = "2022-08-01T00:00:00+0200"
      self.ends_at = "2022-08-05T00:00:00+0200"

    else:
      self.starts_at = "2022-07-23T00:00:00+0200"
      self.ends_at = "2022-08-07T00:00:00+0200"
      

  def __repr__(self):
    return f'#{str(self.id)} ({str(self.stufe)} 👤{str(self.participant_count)}+{str(self.leader_count)} {str(self.week)} {str(self.language)})'

  def from_json(data, mova_scheduler):
    location = mova_scheduler.locations.get("Quartier " + "{:02d}".format(data.get("district_nr")), None)

    unit = Unit(
            id = data.get("id"),
            district = location,
            starts_at = data.get("starts_at"),
            ends_at = data.get("ends_at"),
            language = data.get("language"),
            # participant_count = data.get("participant_role_counts").get("participant") if data.get("participant_role_counts") else 0,
            # leader_count = data.get("participant_role_counts").get("assistant_leader") if data.get("participant_role_counts") else 0,
            participant_count = data.get("expected_participant_counts").get("participant") if data.get("expected_participant_counts") else 0,
            leader_count = data.get("expected_participant_counts").get("leader") if data.get("expected_participant_counts") else 0,
            abteilung = data.get("abteilung", None), 
            stufe = data.get("stufe"),
            week = data.get("week"),
            expected_participant_counts = data.get("expected_participant_counts")
    )

    if data.get("unit_activity_executions") is not None:
      unit.assigned_activities = list(map(lambda data: UnitActivityExecution.from_json(data), data.get("unit_activity_executions")))
  
    if data.get("unit_activities") is not None:
      selected_activities = list(map(lambda data: SelectedActivity.from_json(data, mova_scheduler), data.get("unit_activities")))
      unit.selected_activities = { activity.id: activity for activity in sorted(selected_activities, key=lambda activity: activity.priority) }
  
    return unit

  def size(self):
    return self.participant_count + self.leader_count

  def camp_days(self):
    span = parse(self.ends_at) - parse(self.starts_at)
    return [(parse(self.starts_at) + timedelta(days=day)).strftime("%Y-%m-%d") for day in range(span.days + 1)]

  def assign(self, unit_activity_execution):
    self.assigned_activities.append(unit_activity_execution)

# %% [markdown]
# # Logger

# %%
class Logger:
  def __init__(self, filename, output=False):
    self.console = sys.stdout
    self.output = output
    self.file = None
    self.set_file(filename)

  def set_file(self, filename):
    if self.file:
      self.file.flush()
      self.file.close()
    self.file = open(filename, 'w')

  def write(self, message):
    if self.output:
      self.console.write(str(message) + '\n')
    if self.file:
      self.file.write(str(message) + '\n')

  def flush(self):
    self.console.flush()
    if self.file: 
      self.file.flush()

# %% [markdown]
# # AssignmentError

# %%
class AssignmentError:
  def __init__(self, unit, message, category = None):
    self.unit = unit
    self.category = category
    self.message = str(message)

  def __repr__(self):
    return "Unit: " + str(self.unit) + " Message: " + self.message

# %%
class OverlapError:
  def __init__(self, unit, activity_1, activity_2, required_overlap):
    self.unit = unit
    self.activity_1 = activity_1 if activity_1.id < activity_2.id else activity_2
    self.activity_2 = activity_2 if activity_1.id < activity_2.id else activity_1
    self.required_overlap = required_overlap

  def actual_overlap(self):
    return self.activity_1.overlaps(self.activity_2)

  def activity_ids(self):
    return f'{self.activity_1.id}-{self.activity_2.id}'

  def __repr__(self):
    return f'OverlapError;{self.activity_ids()};{str(self.unit.id)};{self.actual_overlap()};{self.required_overlap};{self.activity_1};{self.activity_2}'

# %%
class TooManyFailuresError(Exception):
  pass

# %% [markdown]
# # Rule Checkers

# %%
class UnitActivityExecutionRuleChecker:
  def __init__(self, mova_scheduler):
    self.mova_scheduler = mova_scheduler
    
  def is_assignable(self, unit_activity_execution, burst=0):
    if not self.rule_no_same_date(unit_activity_execution):
      return "rule_no_same_date"

    if not self.rule_one_excursion_per_week(unit_activity_execution):
      return "rule_one_excursion_per_week"

    if not self.rule_one_aemtli_per_week(unit_activity_execution):
      return "rule_one_aemtli_per_week"

    if not self.rule_one_shower_per_week(unit_activity_execution):
      return "rule_one_shower_per_week"
    
    if not self.rule_during_camp_of_unit(unit_activity_execution):
      return "rule_during_camp_of_unit"
    
    if not self.rule_not_during_ceremony(unit_activity_execution):
      return "rule_not_during_ceremony"
   
    if not self.rule_language_supported(unit_activity_execution):
      return "rule_language_supported"

    if not self.rule_no_activity_twice(unit_activity_execution):
      return "rule_no_activity_twice"

    if not self.rule_one_unit_activity(unit_activity_execution):
      return "rule_one_unit_activity"

    if not self.rule_enough_capacity(unit_activity_execution, burst=burst):
      return "rule_enough_capacity"

    if not self.rule_same_location(unit_activity_execution):
      return "rule_same_location"
    
    if not self.rule_transport_available(unit_activity_execution):
      return "rule_transport_available"

    overlap = self.rule_no_overlaps(unit_activity_execution)
    if overlap is not True:
      return overlap

    return True
  
  def rule_no_activity_twice(self, unit_activity_execution):
    activity_execution = unit_activity_execution.activity_execution
    if activity_execution.activity.category in ["einheitsprogramm", ]:
      return True

    for uae in unit_activity_execution.unit.assigned_activities:
      if uae.activity_execution_id == activity_execution.id:
        return False
      if uae.activity_id == activity_execution.activity_id and uae.activity_id not in [249, 248, 254, 255]:
        return False
    return True

  def rule_not_during_ceremony(self, unit_activity_execution):
    activity_execution = unit_activity_execution.activity_execution
    activity_starts_at = activity_execution.starts_at
    activity_ends_at = activity_execution.ends_at

    for ceremony in ceremonies.get(unit_activity_execution.unit.stufe, []):
      ceremony_starts_at = ceremony[0]
      ceremony_ends_at = ceremony[1]

      if ((ceremony_starts_at <= activity_starts_at and ceremony_ends_at >= activity_starts_at) or 
          (ceremony_starts_at <= activity_ends_at and ceremony_ends_at >= activity_ends_at) or 
          (ceremony_starts_at > activity_starts_at and ceremony_ends_at < activity_ends_at)):
        #print("Ceremony: "+ str(ceremony_starts_at) + " - " + str(ceremony_ends_at) + ", Activity: " + str(activity_starts_at) + " - " + str(activity_ends_at))
        return False 

    return True

  def rule_no_same_date(self, unit_activity_execution):
    ignored_categories = ["taufe", 'einheitsprogramm', 'shower']
    activity_execution = unit_activity_execution.activity_execution
    a = self.mova_scheduler.activities[activity_execution.activity_id]
    if a.category in ignored_categories:
      return True

    for uae in unit_activity_execution.unit.assigned_activities:
      ae = self.mova_scheduler.activity_executions_by_id[uae.activity_execution_id]
      activity = self.mova_scheduler.activities[ae.activity_id]
      if activity.category in ignored_categories:
        continue
      if activity.category == "village_global" and a.category == "village_global":
        continue
      if ae.id == uae.activity_execution_id and len(activity_execution.dates() & ae.dates()) > 0: 
        return False

    return True

  def rule_during_camp_of_unit(self, unit_activity_execution):
    activity_execution = unit_activity_execution.activity_execution
    return unit_activity_execution.unit.starts_at <= activity_execution.starts_at and unit_activity_execution.unit.ends_at >= activity_execution.ends_at
  
  def rule_transport_available(self, unit_activity_execution):
    activity_execution = unit_activity_execution.activity_execution
    result = True
    
    # only check transport if Ausflug
    if activity_execution.has_transport():
      transports_ids = self.mova_scheduler.get_transport(activity_execution.transport_ids)
      if not transports_ids:
        logger.write(activity_execution)
        logger.write(activity_execution.transport_ids)

      for transport in transports_ids:
        result = result and transport.is_unit_assignable(unit_activity_execution.unit)
    
    return result

  def rule_language_supported(self, unit_activity_execution):
    activity_execution = unit_activity_execution.activity_execution
    return (activity_execution.languages == [] or unit_activity_execution.unit.language in activity_execution.languages)

  def rule_enough_capacity(self, unit_activity_execution, burst=0):
    activity_execution = unit_activity_execution.activity_execution
    free = activity_execution.headcount_free()

    return free + burst >= unit_activity_execution.headcount

  def rule_one_unit_activity(self, unit_activity_execution):
    activity_execution = unit_activity_execution.activity_execution

    if activity_execution.activity_id in [220, 221, 222]: 
      return len(activity_execution.assigned_units) <= 0

    if activity_execution.activity.category == "einheitsprogramm": 
      return len(activity_execution.assigned_units) <= 0

    return True

  def rule_one_excursion_per_week(self, unit_activity_execution):
    activity_execution = unit_activity_execution.activity_execution

    if activity_execution.activity.category not in ['hiking', 'culture', 'excursion', 'water']:
      return True

    for uae in unit_activity_execution.unit.assigned_activities:
      if uae.activity_execution.activity.category not in ['hiking', 'culture', 'excursion', 'water']:
        continue
      if activity_execution.week() == uae.activity_execution.week():
        return False 

    return True
  
  def rule_one_aemtli_per_week(self, unit_activity_execution):
    activity_execution = unit_activity_execution.activity_execution

    if activity_execution.activity.category not in ['aemtli']:
      return True

    for uae in unit_activity_execution.unit.assigned_activities:
      if uae.activity_execution.activity.category not in ['aemtli']:
        continue
      if activity_execution.week() == uae.activity_execution.week():
        return False 

    return True
  
  def rule_one_shower_per_week(self, unit_activity_execution):
    activity_execution = unit_activity_execution.activity_execution

    if activity_execution.activity.category not in shower_activities:
      return True

    for uae in unit_activity_execution.unit.assigned_activities:
      if uae.activity_execution.activity.category not in shower_activities:
        continue
      if activity_execution.week() == uae.activity_execution.week():
        return False 

    return True
  
  def rule_same_location(self, unit_activity_execution):
    activity_execution = unit_activity_execution.activity_execution

    if activity_execution.activity.category not in ['aemtli']:
      return True

    if activity_execution.field is None:
      return False

    # super hacky comparison. Those are the same "fields", represented differently
    if not unit_activity_execution.unit.district.cid == activity_execution.field.text:
      return False

    return True

  def rule_no_overlaps(self, unit_activity_execution):
    default_delta = 120
    activity_execution = unit_activity_execution.activity_execution

    for uae in unit_activity_execution.unit.assigned_activities:
      if activity_execution.id == uae.activity_execution_id:
        continue
      if activity_execution.activity.category in ['village_global'] and uae.activity_execution.activity.category == 'village_global':
        continue

      overlap_delta = activity_execution.overlaps(uae.activity_execution)
      if overlap_delta is True:
        return OverlapError(unit_activity_execution.unit, activity_execution, uae.activity_execution, 0) 
        # return False
      else:
        if activity_execution.activity.category == 'visitor_day' or uae.activity_execution.activity.category == 'visitor_day':
          required_delta = timedelta(0)
        elif activity_execution.field is not None and uae.activity_execution.field is not None:
          distance = activity_execution.field.calculate_distance(uae.activity_execution.field)
          if distance is None: 
            distance = 10000
          required_delta = timedelta(minutes=min(150, math.ceil(abs(distance / 50))))
        else:
          required_delta = timedelta(minutes=120)
        
        # if activity_execution.activity.category == 'einheitsprogramm':
        #   # complementing activites don't need delta, neither does visitor_day
        #   if uae.activity_execution.activity.category in ['activity', 'visitor_day']:
        #     continue

        if activity_execution.activity.category == 'shower' and uae.activity_execution.activity.category == 'shower':
          required_delta = timedelta(days=5)
        
        if overlap_delta < required_delta:
          
          # print(str(overlap_delta))
          # print(str(required_delta))
          # print("----")
          return OverlapError(unit_activity_execution.unit, activity_execution, uae.activity_execution, required_delta) 

    return True

# %%
class UnitActivityRuleChecker:
  def __init__(self, unit_scheduler):
    self.unit = unit_scheduler.unit
    self.unit_scheduler = unit_scheduler

  def is_assignable(self, activity):
    if not self.rule_mova_activity_assignable(activity):
      return "rule_mova_activity_assignable"

    if not self.rule_stufe_assignable(activity):
      return "rule_stufe_assignable"

    if not self.rule_hiking_assignable(activity):
      return "rule_hiking_assignable"
    
    if not self.rule_taufe_assignable(activity):
      return "rule_taufe_assignable"
    
    if not self.rule_frohnarbeit_assignable(activity):
      return "rule_frohnarbeit_assignable"

    if not self.rule_excursions_assignable(activity):
      return "rule_excursions_assignable"

    if not self.rule_village_global_assignable(activity):
      return "rule_village_global_assignable"

    if not self.rule_no_activity_twice_assignable(activity):
      return "rule_no_activity_twice_assignable"

    if not self.rule_no_special_activities(activity):
      return "rule_no_special_activities"

    return True

  
  def rule_no_special_activities(self, activity):
    return not activity.id in [225] # Besuchstage

  def rule_mova_activity_assignable(self, activity):
    if activity.category != 'activity': 
      return True

    activity_count = self.unit_scheduler.mova_activity_count()
    return activity_count < { 'wolf': 1, 'pta': 2, 'pfadi': 3, 'pio': 3 }.get(self.unit.stufe, 0)

  def rule_taufe_assignable(self, activity):
    if activity.category != "taufe":
      return True

    groups = self.unit_scheduler.group_unit_activity_executions_by_category()
    count = len(groups.get("taufe", []))
    return count < 1

  def rule_frohnarbeit_assignable(self, activity):
    if activity.category != "frohnarbeit":
      return True

    groups = self.unit_scheduler.group_unit_activity_executions_by_category()
    count = len(groups.get("frohnarbeit", []))
    return count < 1

  def rule_no_activity_twice_assignable(self, activity):
    for uae in self.unit.assigned_activities:
      assigned_activity_id = uae.activity_id
      if assigned_activity_id == activity.id and assigned_activity_id not in [249, 248]:
        return False
    return True

  def rule_village_global_assignable(self, activity):
    if activity.category != 'village_global': 
      return True

    assigned_participants = 0
    for uae in self.unit_scheduler.group_unit_activity_executions_by_category().get('village_global', []):
      assigned_participants += uae.headcount

    return assigned_participants < self.unit.participant_count


  def rule_excursions_assignable(self, activity):
    if activity.category not in ['excursion', 'culture', 'sport', 'water']: 
      return True

    if self.unit_scheduler.excursions_count() < 1 and self.unit_scheduler.hikings_count() < 2:
      return True

    return False

  def rule_hiking_assignable(self, activity):
    if activity.category != 'hiking': 
      return True

    if activity.id in two_day_hikes:
      if self.unit.stufe not in ['pfadi', 'pio']:
        return False
      return self.unit_scheduler.hikings_count() <= 0 and self.unit_scheduler.excursions_count() <= 0

    combined_count = self.unit_scheduler.excursions_count() + self.unit_scheduler.hikings_count()
    return combined_count < { 'wolf': 1, 'pta': 1, 'pfadi': 2, 'pio': 2 }.get(self.unit.stufe, 0)

  def rule_stufe_assignable(self, activity):
    activity = self.unit_scheduler.mova_scheduler.activities[activity.id]
    if activity.stufen == []:
      raise RuntimeError("keine Stufen: " + str(activity))
    return self.unit.stufe in activity.stufen

  def needs_more_of(self, phase=4):
    hikings_count = self.unit_scheduler.hikings_count()
    activities = self.unit_scheduler.mova_scheduler.activities
    activity_executions_by_category = self.unit_scheduler.count_unit_activity_executions_by_category()

    if phase == 4:
      if hikings_count < { 'wolf': 0, 'pta': 0, 'pfadi': 1, 'pio': 1 }.get(self.unit.stufe, 0):
        joker = joker_hikings.get(self.unit.id, 24)
        if joker:
          return { "hikings": [self.unit_scheduler.mova_scheduler.activities[joker]] }
        return { "hikings": [] }

      if hikings_count + self.unit_scheduler.excursions_count() < { 'wolf': 1, 'pta': 0, 'pfadi': 2, 'pio': 2 }.get(self.unit.stufe, 0):
        return { "excursion": [self.unit_scheduler.mova_scheduler.activities[activity_id] for activity_id in safe_excursions] }

      if self.unit_scheduler.mova_activity_count() < { 'wolf': 1, 'pta': 2, 'pfadi': 3, 'pio': 3 }.get(self.unit.stufe, 0):
        return { "mova_activity": [activity for activity in activities.values() if activity.category == 'activity'] }

      if activity_executions_by_category.get('aemtli', 0) < { 'wolf': 1, 'pta': 0, 'pfadi': 2, 'pio': 2 }.get(self.unit.stufe, 0):
        return { "aemtli": [activities[249]] }

    if phase == 7:
      shower_count = len([value for value in self.unit_scheduler.assigned_activity_ids() if value in shower_activities])
      if shower_count < { 'wolf': 1, 'pta': 1, 'pfadi': 2, 'pio': 2 }.get(self.unit.stufe, 0):
        return { "shower": [activities[248]] }

    return False

# %% [markdown]
# # VillageGlobalScheduler

# %%
class VillageGlobalScheduler:
  def __init__(self, unit_scheduler):
    self.unit_scheduler = unit_scheduler
    self.unit = unit_scheduler.unit
    self.slot = None
    self.best_slot_assignments = []
    self.headcount_to_assign = 0

  def is_assignable(self, activity_execution):

    if activity_execution.activity.category != "village_global":
      return "not a village global activity"
    
    if self.unit.stufe not in activity_execution.activity.stufen:
      return f'stufe {self.unit.stufe} cannot participate in {activity_execution.activity.stufen}'
    
    for uae in activity_execution.assigned_units:
      if uae.unit.stufe != self.unit.stufe:
        return f'dont mix stufen: {uae.unit.stufe} <- {self.unit.stufe}'
    
    if activity_execution.headcount_free() <= 0:
      return "no seat left in this exection"

    return True
   
  def slots(activity_executions):
    slots = {}
    for activity_execution in activity_executions:
      if activity_execution.activity.category == "village_global":
        slot = activity_execution.starts_at
        if slot in slots: slots[slot].append(activity_execution)
        else: slots[slot] = [activity_execution]
    # return sorted(slots.items(), key=lambda slot: slot)
    return slots

  def find_best_slot(self):
    logger.write("  ==> Finding best slot for " + str(self.unit))
    highscore = None
    best_slot_assignments = None
    best_slot = None

    slots = list(self.unit_scheduler.mova_scheduler.village_global_slots.items())
    slots = sorted(slots, key=lambda slotpair: sum([uae.headcount for ae in slotpair[1] for uae in ae.assigned_units]), reverse=True)
    slots = MovaScheduler.cluster_shuffle(slots, cluster_size=5)

    for slot, activity_executions in slots:
      logger.write("   * " + slot)
      possible_assignments = self.possible_assignments_in_slot(activity_executions)

      if possible_assignments == []:
        logger.write("     x no assignments possible in this slot")
        continue

      slot_score = sum([uae.score for uae in possible_assignments])
      logger.write("     = Slot has a score of " + str(slot_score))

      if highscore is None or slot_score > highscore:
        best_slot = slot 
        best_slot_assignments = possible_assignments
        highscore = slot_score

    if best_slot is None:
      logger.write("   = X no slot could be found")
      return False

    logger.write("   = Choosing best slot " + best_slot + " with score of " + str(highscore))

    self.slot = best_slot
    self.slot_assignments = best_slot_assignments
    return best_slot_assignments

  def possible_assignments_in_slot(self, activity_executions_of_slot):
    possible_assignments = []
    subgroup_size = 12
    subgroups = [subgroup_size] * math.floor(self.unit.participant_count / subgroup_size)
    rest = self.unit.participant_count % subgroup_size
    if rest <= 12:
      subgroups[-1] += rest 
    else:
      subgroups.append(rest)

    subgroups.sort(reverse=True)
   
    for execution in activity_executions_of_slot:
      score = self.unit_scheduler.activity_score(execution.activity_id)
      score += max(3 - len(execution.stufen), 0) / 6
      score += max(3 - len(execution.languages), 0) / 6
      score = round(score, 1)
      assignment = self.is_assignable(execution)

      if assignment is True:
        uae = UnitActivityExecution(unit=self.unit, activity_execution=execution, score=score, headcount=0, phase=2)
        possible_assignments.append(uae)
      #   logger.write("     + Asignment candidate " + str(execution))
      # else:
      #   logger.write("     x " + str(self.unit.id) + str(execution) + ": " + assignment)

    possible_assignments = sorted(possible_assignments, key=lambda uae: (uae.score, uae.activity_execution.headcount_free()), reverse=True)
    best_possible_assignments = []

    logger.write("     - Subgroups: " + str(subgroups))

    for uae in possible_assignments:
      if len(subgroups) <= 0:
        break

      logger.write("     * " + str(uae.activity_execution))
      free = uae.activity_execution.headcount_free()
      headcount = 0
      remaining_subgroups = []
      subgroups_was = list(subgroups)
      burst = 4

      while True:
        if len(subgroups) <= 0:
          break
        subgroup = subgroups.pop(0)

        if headcount + subgroup <= free:
          headcount += subgroup
        elif len(subgroups) <= 0 and (free + burst) >= (headcount + subgroup):
          headcount += subgroup
          logger.write("       $$$ Burst: " + str(headcount) + " into " + str(free))
        else:
          remaining_subgroups.append(subgroup)

      if headcount <= 0:
        subgroups = subgroups_was
        logger.write("       x " + str(uae) + ": no space for subgroup")
        continue

      uae.headcount = headcount
      assignable = self.unit_scheduler.execution_rule_checker.is_assignable(uae, burst=burst)

      if assignable is True:
        logger.write("       + Assignment candidate " + str(uae))
        best_possible_assignments.append(uae)
        subgroups = remaining_subgroups
      else:
        logger.write("       x " + str(uae) + ": " + assignable)
        subgroups = subgroups_was
        continue

    if len(subgroups) <= 0:
      return best_possible_assignments

    return []

# %% [markdown]
# # UnitfieldScheduler

# %%
from dateutil.parser import parse

class FieldRequirement:
  def __init__(self, scheduler, date, complementing = None):
    self.scheduler = scheduler
    self.complementing = complementing
    self.date = date
    self.location = scheduler.unit.district
    self.size = scheduler.unit.participant_count
    self.derive_from_complementing()
    
  def derive_from_complementing(self):
    if self.complementing is None:
      return 

    activity_execution = self.complementing.activity_execution
    start_time = activity_execution.starts_at.split("T")[1]
    self.location = activity_execution.field

  def assignment_order(self):
    if self.complementing is not None:
      if self.size > 75:
        return 1
      else:
        return 2
    else:
      if self.size > 75:
        return 3
      else:
        return 4
   
  def __repr__(self):
    return "Requirement #" + str(self.scheduler.unit.id) + " @" + str(self.date) + ", Location: " + str(self.location)

  def fits_complementing(self, unit_activity_execution):
    if self.complementing is None:
      return True

    if self.complementing.activity_execution.activity.category in ['activity']:
      cae = self.complementing.activity_execution
      oae = unit_activity_execution.activity_execution
      diff = lambda date1, date2: abs((parse(date1) - parse(date2)))
      return diff(cae.starts_at, oae.ends_at) <= timedelta(minutes=60) or diff(cae.ends_at, oae.starts_at) <= timedelta(minutes=60)

    return True

  def fits(self, unit_activity_execution):
    if not self.fits_complementing(unit_activity_execution):
      return "not_complementing_for: " + str(self.complementing) + " --- "
    # if self.size < 75 and unit_activity_execution.activity_execution.headcount_free() > 75:
    #   return "leave_field_to_bigger_units"

    return self.scheduler.execution_rule_checker.is_assignable(unit_activity_execution)

# %%
class UnitfieldScheduler:
  def __init__(self, unit, mova_scheduler):
    self.unit = unit
    self.field_requirements = [] #self.collect_field_requirements()
    self.assigned_fields = []
    self.mova_scheduler = mova_scheduler
    self.execution_rule_checker = UnitActivityExecutionRuleChecker(self.mova_scheduler)

  def __repr__(self):
    return str(self.unit) + " " + str(self.happyness())

  def collect_field_requirements(self):
    requirement_days = { day: [] for day in self.unit.camp_days() }
    ceremony_days = ["2022-07-24", "2022-08-01", "2022-08-04"]

    for ceremony in ceremonies.get(self.unit.stufe, []):
      ceremony_days.append(ceremony[0].split("T")[0])
    
    # remove non programm days
    requirement_days.popitem()
    if "2022-07-23" in requirement_days.keys(): requirement_days.pop("2022-07-23") 
    if "2022-08-06" in requirement_days.keys(): requirement_days.pop("2022-08-06")

    for uae in self.unit.assigned_activities:
      day = next(iter(uae.activity_execution.dates()))

      if day not in requirement_days or requirement_days[day] is None:
        continue

      # collect all mova activity days (mova activity or visiting day)
      if uae.activity_execution.activity.category in ['activity']:
        requirement_days[day] = [FieldRequirement(scheduler=self, complementing=uae, date=day)]
        continue

      if uae.activity_execution.activity.category in ['frohnarbeit']:
        requirement_days[day] = [FieldRequirement(scheduler=self, date=day)]
        continue

      if uae.activity_execution.activity.category in ['visitor_day', 'village_global', 'aemtli']:
        requirement_days[day] = [FieldRequirement(scheduler=self, date=day)]
        continue

      if uae.activity_execution.activity.category in ['hiking', 'excursion', 'culture', 'water']:
        for day in uae.activity_execution.dates():
          requirement_days[day] = None
        continue

    for day, day_requirements in requirement_days.items():
      if day_requirements is None:
        continue

      # no mova days, two fields requried 
      if day_requirements == []:
        requirement_days[day] = [FieldRequirement(scheduler=self, date=day)]                 
      
        if day not in ceremony_days and day != "2022-08-05":
          requirement_days[day].append(FieldRequirement(scheduler=self, date=day))     
    
    requirements = []

    for day_requirements in requirement_days.values():
      if day_requirements is not None:
        for requirement in day_requirements:
          requirements.append(requirement)

    return requirements
    
  def happyness(self):
    if len(self.field_requirements) == 0:
      return 0
    return len(self.assigned_fields) / len(self.field_requirements)

  def pick(self, activity_executions, requirement):
    logger.write("    * " + str(requirement))

    for ae in activity_executions:
      uae = UnitActivityExecution(unit=self.unit, activity_execution=ae, phase=4)
      fit = requirement.fits(uae)
      if fit is not True:
        if fit not in ['rule_one_unit_activity']:
          logger.write("      x "+ fit + ": " + str(uae))
        continue
   
      logger.write("     +  Assigned " + str(uae))
      uae.assign()
      self.assigned_fields.append(uae)
      return True
        
    return False

# %% [markdown]
# # MovaScheduler

# %%
import random

class MovaScheduler:
  def __init__(self, loader):
    self.loader = loader
    self.activities = {}
    self.units = []
    self.activity_executions_by_activity_id = {}
    self.unit_schedulers = {}
    self.score = {
        "happyness": 0,
        "pissedness": 0
    }
    self.errors = []
    self.locations = {}
    self.transports = {}

  def __repr__(self):
    return str(self.score) + ", " + str(len(self.errors)) + " Errors"

  def load(self):
    self.locations = { location.cid: location for location in list(map(lambda data: Location.from_data(data), loader.load_locations())) }
    self.transports = { transport.id: transport for transport in list(map(lambda data: Transport.from_data(data), loader.load_transports())) }
    self.activities = { activity.id: activity for activity in list(map(lambda data: Activity.from_json(data, self), loader.fetch_activities())) }
    self.activity_executions_by_activity_id = { id: self.activities[id].activity_executions for id in self.activities }
    self.units = list(map(lambda data: Unit.from_json(data, self), loader.fetch_units()))
    self.unit_schedulers = dict(map(lambda unit: (unit.id, UnitScheduler(unit, self)), self.units))
    self.field_schedulers = {}
    self.activity_executions_by_id = { activity_execution.id: activity_execution for activity in self.activities.values() for activity_execution in activity.activity_executions }
    self.village_global_slots = VillageGlobalScheduler.slots(self.activity_executions_by_id.values())
    self.village_global_activities = [activity for activity in self.activities.values() if activity.category == 'village_global']
    self.unit_activity_executions =self.assign_preassigned_unit_activity_executions()
    self.fields = [activity for activity in self.activities.values() if activity.category == 'einheitsprogramm']
    self.einheitsprogramm_by_distance_cache = {}
    self.einheitsprogramm_by_date = self.load_einheitsprogramm_by_date()
    self.field_schedulers = { unit.id: UnitfieldScheduler(unit, self) for unit in self.units }

  def assign_preassigned_unit_activity_executions(self):
    unit_activity_executions = []
    if run_sideload:
      for unit_scheduler in self.unit_schedulers.values():
        unit_scheduler.unit.assigned_activities = []

      reader = csv.reader(sideload_csv.splitlines(), delimiter=',')
      next(reader)

      for row in reader:
        if int(row[0]) not in self.unit_schedulers.keys():
          continue
        unit = self.unit_schedulers[int(row[0])].unit
        activity_execution = self.activity_executions_by_id[int(row[1])]
        headcount = int(row[2])
        phase = row[3]
        score = row[4]
        uae = UnitActivityExecution(unit=unit, activity_execution=activity_execution, headcount=headcount, phase=phase, score=score)
        unit.assigned_activities.append(uae)  

    for unit_scheduler in self.unit_schedulers.values():
      for uae in unit_scheduler.unit.assigned_activities:
        unit_activity_executions.append(uae)
        if uae.unit is None:
          uae.unit = unit_scheduler.unit
        if uae.activity_execution is None:
          uae.activity_execution = self.activity_executions_by_id[uae.activity_execution_id]
        uae.activity_execution.assign(uae)

    return unit_activity_executions


  def get_transport(self, id):
    if id is None: 
      return None

    ids = id.split(",")
    locations = []

    try:
      # check if multiple transports have been givne
      for loc in ids:
        locations.append(self.transports[loc])
    except:
      raise RuntimeError("Transport " + id + " nicht gefunden")
    
    return locations

  def get_least_happy_unit_schedulers(self, unit_schedulers):
    min = None 
    unhappy_schedulers = []
    for scheduler in unit_schedulers:
      scheduler_happyness = scheduler.happyness  #- sum(scheduler.activity_score(activity.id) for activity in scheduler.unassigned_activities])
      if min is None or scheduler_happyness < min:
        min = scheduler_happyness
        unhappy_schedulers = [scheduler]
      elif scheduler_happyness == min:
        unhappy_schedulers.append(scheduler)
    
    return unhappy_schedulers


  def phase_1_visitor_day(self):
    abteilungen_with_score = {}
    main_activity = self.activities[223]
    unit_schedulers = sorted(self.unit_schedulers.values(), key=lambda us: us.activity_score(main_activity.id), reverse=True)
    
    for unit_scheduler in unit_schedulers:
      abteilung = unit_scheduler.unit.abteilung
      score =  unit_scheduler.activity_score(main_activity.id)
      if abteilung in abteilungen_with_score.keys():
        abteilungen_with_score[abteilung] += score
      else:
        abteilungen_with_score[abteilung] = score

    abteilungen_with_score = dict(sorted(abteilungen_with_score.items(), key=lambda a: a[1], reverse=True))
    logger.write(str(abteilungen_with_score))
    executions = sorted(self.activity_executions_by_activity_id[main_activity.id], key=lambda execution: { 56517: 1, 56516: 1, 56518: 2, 56515: 2, 56514: 3 }.get(execution.id, 4))

    for abteilung, abteilung_score in abteilungen_with_score.items():
      logger.write(f' * Abteilung: {abteilung}: {abteilung_score}')
      
      for unit_scheduler in unit_schedulers:
        if unit_scheduler.unit.abteilung != abteilung:
          continue
        if unit_scheduler.activity_rule_checker.is_assignable(main_activity) is not True:
          continue
        if unit_scheduler.unit.stufe not in ["pfadi", "pio"]:
          continue

        score = unit_scheduler.activity_score(main_activity.id)
        logger.write(f'   * Einheit: {unit_scheduler.unit}: {score}')
      
        executions = MovaScheduler.cluster_shuffle(executions, cluster_size=2)
        for execution in executions:
          if execution.id in [56513, 56514] and unit_scheduler.unit.language == "it":
            continue
        #  if execution.id in [56513, 56514, 56515, 56520, 56521] and unit_scheduler.unit.language == "fr":
        #    continue
          uae = UnitActivityExecution(unit=unit_scheduler.unit, activity_execution=execution, score=score, headcount=unit_scheduler.unit.size(), phase=1)
          logger.write(f'     * {uae}')
          assignability = unit_scheduler.execution_rule_checker.is_assignable(uae)

          if assignability is True:
            logger.write(f'     + {score}')
            uae.assign()
            # unit_scheduler.happyness += score
            break
          # else:
          #   logger.write(f'       x {assignability}')

  def phase_3_wishlist(self):
    logger.write("===== PHASE 3 =====")

    for scheduler in self.unit_schedulers.values():  
      scheduler.recalculate_happyness()
      
    while True:
      available_schedulers = list(filter(lambda scheduler: len(scheduler.wishlist) > 0, self.unit_schedulers.values()))
      if len(available_schedulers) <= 0:
        break;

      pool = list(self.get_least_happy_unit_schedulers(available_schedulers))
      pool = sorted(pool, key=lambda scheduler: scheduler.unit.size(), reverse=True)
      pool = MovaScheduler.cluster_shuffle(pool, cluster_size=3)
      for scheduler in pool:
        logger.write("")
        logger.write(scheduler)
        scheduler.wishlist_assignment()

  def phase_2_village_global_slot(self):
    failures = []
    logger.write("===== PHASE 2: Village Global =====")
    schedulers = sorted(self.unit_schedulers.values(), key=lambda scheduler: scheduler.unit.participant_count, reverse=True)
 
    for unit_scheduler in schedulers:
      if unit_scheduler.unit.stufe in ["pta"]:
        continue
      if unit_scheduler.unit.week in ["", None]:
        continue
      score_sum = sum([unit_scheduler.activity_score(a.id) for a in unit_scheduler.unit.selected_activities.values() if a.category == 'village_global'])
      logger.write(str(unit_scheduler.unit) + ": " + str(score_sum))
      if not unit_scheduler.village_global_assignment():
        self.errors.append(AssignmentError(unit=unit_scheduler.unit, category="Village Global"))
        failures.append(unit_scheduler)
        # if len(failures) > failures_threshold:
        raise TooManyFailuresError()

    for unit_scheduler in schedulers:
      if unit_scheduler.unit.stufe in ["pta"]:
        continue
      score_sum = sum([unit_scheduler.activity_score(a.id) for a in unit_scheduler.unit.selected_activities.values() if a.category == 'village_global'])
      logger.write(str(unit_scheduler.unit) + ": " + str(score_sum))
      if not unit_scheduler.village_global_assignment():
        self.errors.append(AssignmentError(unit=unit_scheduler.unit, category="Village Global", message=""))
        failures.append(unit_scheduler)
        # if len(failures) > failures_threshold:
        raise TooManyFailuresError()

  def phase_4_min_requirements(self):
    failures = []
    logger.write("===== PHASE 4: Minimal Activities =====")
    schedulers = sorted(self.unit_schedulers.values(), key=lambda scheduler: scheduler.unit.participant_count, reverse=True)
    schedulers = MovaScheduler.cluster_shuffle(schedulers, cluster_size=10)
    for unit_scheduler in schedulers:
      logger.write("")
      logger.write(unit_scheduler)
      problem = unit_scheduler.missing_activity_assignments(phase=4)
      if problem is not True:
        self.errors.append(AssignmentError(unit=unit_scheduler.unit, category="Minimal Activities", message=problem))
        failures.append(unit_scheduler)
        if len(failures) > failures_threshold:
          raise TooManyFailuresError()

  
  def phase_5_pio_workshops(self):
    logger.write("===== PHASE 5: Pio Workshops =====")
    am_workshops = self.activity_executions_by_activity_id[254]
    pm_workshops = self.activity_executions_by_activity_id[255]
    headcount_free = lambda aes: sum([ae.headcount_free() for ae in aes])
    no_workshop_days = ["2022-07-23", "2022-07-24", "2022-08-06", "2022-08-07", "2022-08-05"]
    schedulers = list(self.unit_schedulers.values())
    random.shuffle(schedulers)

    for scheduler in schedulers:
      if scheduler.unit.stufe != "pio": continue
      workshops = am_workshops if headcount_free(am_workshops) > headcount_free(pm_workshops) else pm_workshops

      requirement_days = { day: [] for day in scheduler.unit.camp_days() }
      for day in no_workshop_days:
        if day in requirement_days.keys(): requirement_days.pop(day) 

      for uae in scheduler.unit.assigned_activities:
        if uae.activity_execution.activity.category not in []:
          for day in uae.activity_execution.dates():
            if day in requirement_days.keys(): requirement_days.pop(day)

      logger.write(" * " + str(scheduler.unit))
      for workshop in workshops:
        day = next(iter(workshop.dates()))
        if day in requirement_days:
          uae = UnitActivityExecution(unit=scheduler.unit, activity_execution=workshop, phase=5, score=10)
          logger.write(f'    * {uae}')
          assignability = scheduler.execution_rule_checker.is_assignable(uae)
       
          if assignability is True:
            logger.write(f'     + {uae.score}')
            uae.assign()
            requirement_days.pop(day)    
          else:
            logger.write(f'     x {assignability}')

      for day in requirement_days:
        self.errors.append(AssignmentError(unit=scheduler.unit, category="Pio Workshop", message=f'{day}'))
        if len(self.errors) > failures_threshold:
          raise TooManyFailuresError()
  
  def phase_6_einheitsprogramm(self):
    logger.write("===== PHASE 6: Einheitsflächen =====")
    requirements_by_assignment_order  = {}

    for scheduler in self.field_schedulers.values():
      for requirement in scheduler.collect_field_requirements():
        logger.write(" * " + str(requirement))
        assignment_order = requirement.assignment_order()

        if assignment_order not in requirements_by_assignment_order.keys():
          requirements_by_assignment_order[assignment_order] = []
        requirements_by_assignment_order[assignment_order].append(requirement)

    requirements_by_assignment_order = dict(sorted(requirements_by_assignment_order.items()))

    for assignment_order, requirements in requirements_by_assignment_order.items():
      random.shuffle(requirements)

      for requirement in requirements:
        scheduler = requirement.scheduler
        logger.write("")
        logger.write(scheduler)
        
        # Get all executions, presorted by distance from quartier  
        aes = self.einheitsprogramm_by_distance(scheduler.unit.district).get(requirement.date, [])
      
        if not scheduler.pick(aes, requirement):
          self.errors.append(AssignmentError(unit=scheduler.unit, category="Einheitsprogramm", message=f'{requirement.date};{requirement.location.cid}'))
          logger.write("  xxx could not fullfill requirement: " + str(requirement))
          if len(self.errors) > failures_threshold:
            raise TooManyFailuresError()

  def phase_7_showers(self):
    logger.write("===== PHASE 7: Showers =====")
    schedulers = sorted(self.unit_schedulers.values(), key=lambda scheduler: scheduler.unit.participant_count, reverse=True)
    schedulers = MovaScheduler.cluster_shuffle(schedulers, cluster_size=10)

    for unit_scheduler in schedulers:
      logger.write("")
      logger.write(unit_scheduler)
      problem = unit_scheduler.missing_activity_assignments(phase=7)
      if problem is not True:
        self.errors.append(AssignmentError(unit=unit_scheduler.unit, category="Minimal Activities", message=problem))
        if len(self.errors) > failures_threshold:
          raise TooManyFailuresError()

  def rerun_activity_execution_checks(self):
    schedulers = sorted(list(self.field_schedulers.values()), key=lambda scheduler: scheduler.unit.participant_count, reverse=True)

    for scheduler in schedulers:
      overlap_errors = []
      logger.write(f' * {scheduler.unit}')

      for uae in scheduler.unit.assigned_activities:
        no_overlaps = scheduler.execution_rule_checker.rule_no_overlaps(uae)
        category = uae.activity_execution.activity.category
      
        if no_overlaps is not True:
          logger.write(f'     x {no_overlaps}')
          other_activity = no_overlaps.activity_2 if no_overlaps.activity_1.id == uae.activity_execution_id else no_overlaps.activity_1

          if category == 'einheitsprogramm' and other_activity.activity.category == 'activity':            
            logger.write(f'       Removing {uae}')
            uae.activity_execution.assigned_units.remove(uae)
            uae.unit.assigned_activities.remove(uae)
            scheduler.field_requirements.append(no_overlaps)

            best_replacement = None
            best_replacement_delta = None

            for replacement in self.einheitsprogramm_by_date[next(iter(uae.activity_execution.dates()))]:
              replacement_uae = UnitActivityExecution(unit= scheduler.unit, activity_execution=replacement, headcount=uae.headcount, score=uae.score, phase=9)
              
              if scheduler.execution_rule_checker.is_assignable(replacement_uae) is not True:
                continue
              
              replacement_delta = replacement.overlaps(other_activity)

              if best_replacement_delta is None or replacement_delta < best_replacement_delta:
                logger.write(f'         {replacement_delta} < {best_replacement_delta}')
                best_replacement = replacement_uae
                best_replacement_delta = replacement_delta
                logger.write(f'       + {replacement_uae}')

            if best_replacement is None:
              if no_overlaps.activity_ids() not in overlap_errors:
                overlap_errors.append(no_overlaps.activity_ids())
                self.errors.append(AssignmentError(unit=scheduler.unit, category=category, message=f'{no_overlaps}'))
            else:
              best_replacement.assign()
              scheduler.assigned_fields.append(best_replacement)
              logger.write(f'   +++ {best_replacement}')
  
          else:
            if category == 'activity' and other_activity.activity.category == 'einheitsprogramm':
              continue

            if no_overlaps.activity_ids() not in overlap_errors:
              logger.write(f'     x {no_overlaps}')
              overlap_errors.append(no_overlaps.activity_ids())
              self.errors.append(AssignmentError(unit=scheduler.unit, category=category, message=f'{no_overlaps}'))

  def fix_forbidden_fields_on_05_08(self):
    stufen_order = list(einheitsprogramm_spots.keys())
    # schedulers = sorted(list(self.field_schedulers.values()), key=lambda scheduler: scheduler.unit.participant_count, reverse=True)
    schedulers = sorted(list(self.field_schedulers.values()), key=lambda scheduler: stufen_order.index(scheduler.unit.stufe))
    MovaScheduler.cluster_shuffle(schedulers, cluster_size=1000)

    # spot_ok = lambda unit, field: field.id in einheitsprogramm_spots[unit.stufe]

    for round in range(1):
      for scheduler in schedulers:
        unit = scheduler.unit
      
        for uae in unit.assigned_activities:
          if uae.activity_execution.activity.category not in ['einheitsprogramm']: 
            continue

          date = next(iter(uae.activity_execution.dates()))

          if date != "2022-08-05":
            continue
          
          if uae.activity_execution.field.id in allowed_fields_05_08:
            continue

          replacement_uae = self.replace_einheitsprogramm(scheduler, uae, field_ids=allowed_fields_05_08, activity_ids=[uae.activity_execution.activity_id], max_fallback_level=2, log=True, base_phase=40)
          
          if replacement_uae is None:
            self.errors.append(AssignmentError(unit=scheduler.unit, category='einheitsprogramm', message=f'No Replacement found for {uae}'))
          else:
            replacement_uae.assign()

  def reassign_einheitsprogramm_fields(self):
    stufen_order = list(einheitsprogramm_spots.keys())
    # schedulers = sorted(list(self.field_schedulers.values()), key=lambda scheduler: scheduler.unit.participant_count, reverse=True)
    schedulers = sorted(list(self.field_schedulers.values()), key=lambda scheduler: stufen_order.index(scheduler.unit.stufe))
    spot_ok = lambda unit, field: field.id in einheitsprogramm_spots[unit.stufe]
    MovaScheduler.cluster_shuffle(schedulers, cluster_size=25)

    for round in range(2):
    
      to_replace = []

      for scheduler in schedulers:
        unit = scheduler.unit
        einheitsprogramm_per_day = {}
        activities_to_have = [250, 251, 252, 253]

        for uae in unit.assigned_activities:
          if uae.activity_execution.activity.category not in ['einheitsprogramm', 'activity']: 
            continue

          date = next(iter(uae.activity_execution.dates()))

          if date not in einheitsprogramm_per_day.keys():
            einheitsprogramm_per_day[date] = []

          einheitsprogramm_per_day[date].append(uae)
          if uae.activity_execution.activity_id in activities_to_have:
            activities_to_have.remove(uae.activity_execution.activity_id)

        for date, einheitsprogramm_on_day in einheitsprogramm_per_day.items():

          complementary_activity = None
          for uae in einheitsprogramm_on_day:
            if uae.activity_execution.activity.category != 'einheitsprogramm':
              complementary_activity = uae

          for uae in einheitsprogramm_on_day:
            if uae.activity_execution.activity.category != 'einheitsprogramm':
              continue


            field_ids=einheitsprogramm_spots[unit.stufe]

            if complementary_activity is not None:
              complementary_activity_spot_id = next((spot_id for spot_id, field_ids in programmspots_fields.items() if complementary_activity.activity_execution.field.id in field_ids), None)
              einheitsprogramm_spot_id = next((spot_id for spot_id, field_ids in programmspots_fields.items() if uae.activity_execution.field.id in field_ids), None)
              
              if complementary_activity_spot_id is None:
                field_ids = programmspots_fields[7]
              else:
                if complementary_activity_spot_id == einheitsprogramm_spot_id:
                  continue
                else:
                  field_ids = programmspots_fields[complementary_activity_spot_id]
              # else:
                #self.errors.append(AssignmentError(unit=scheduler.unit, category='einheitsprogramm', message=f'Is not on same spot as activity {uae} to {complementary_activity};{complementary_activity.activity_execution.field.text[0]}'))
              #  logger.write(f'   ! @{uae.activity_execution.field.text} !!! {complementary_activity.activity_execution.field.text}')
            else:
              if spot_ok(unit, uae.activity_execution.field) and not (date == "2022-08-05" and uae.activity_execution.field.id in programmspots_fields[4]):
                continue

            # if uae.activity_execution.field.id in last_resort_forest_fields and 
            if str(uae.phase) not in ['4', '9', '10', '11']: 
              continue

            replacement_uae = self.replace_einheitsprogramm(scheduler, uae, field_ids=field_ids, activity_ids=activities_to_have, max_fallback_level=round + 2, log=round >= 1, base_phase=(round + 1) * 10)
            
            if replacement_uae is None:
              if round >= 1:
                category = 'einheitsprogramm' if complementary_activity is None else 'complementary'
                self.errors.append(AssignmentError(unit=scheduler.unit, category=category, message=f'No Replacement found for {uae}'))
            else:
              replacement_uae.assign()
              if replacement_uae.activity_execution.activity_id in activities_to_have:
                activities_to_have.remove(replacement_uae.activity_execution.activity_id)

        if len(activities_to_have) > 1:
          if 252 in activities_to_have and 253 in activities_to_have:
            for uae in unit.assigned_activities:
              if uae.activity_execution.activity_id not in [250, 251]: 
                continue

              replacement_uae = self.replace_einheitsprogramm(scheduler, uae, field_ids=field_ids, activity_ids=[252, 253], max_fallback_level=0, log=round >= 1)
            
              if replacement_uae is not None:
                replacement_uae.assign()
                if replacement_uae.activity_execution.activity_id in activities_to_have:
                  activities_to_have.remove(replacement_uae.activity_execution.activity_id)
            
            if len(activities_to_have) > 1:
              retry_missing = self.swap_unit_activity_executions(scheduler, missing=activities_to_have)
              if len(retry_missing) > 0 and round >= 1:
                self.errors.append(AssignmentError(unit=scheduler.unit, category='einheitsprogramm', message=f'Missing activities {activities_to_have}'))


  def replace_einheitsprogramm(self, scheduler, uae_to_replace, field_ids=None, activity_ids=None, fallback_level=0, max_fallback_level=3, log=False, base_phase=10):

    if uae_to_replace in scheduler.unit.assigned_activities: 
      scheduler.unit.assigned_activities.remove(uae_to_replace) 
    if uae_to_replace in uae_to_replace.activity_execution.assigned_units: 
      uae_to_replace.activity_execution.assigned_units.remove(uae_to_replace)
    available_activity_executions = sorted(self.einheitsprogramm_by_date[next(iter(uae_to_replace.activity_execution.dates()))], key=lambda ae: ae.amount_participants)

    if log: logger.write(f'   * Replace {uae_to_replace.activity_execution} : {field_ids}')
    
    for replacement in available_activity_executions:
      if len(replacement.assigned_units) > 0:
        continue

      if log: 
        logger.write(f'     - with {replacement} ?')

      if fallback_level < 1:
        if replacement.activity_id not in activity_ids:
          if log: logger.write(f'         x not correct activity {replacement.activity_id}, should be: {activity_ids}')
          continue 

      if fallback_level < 2:
        overlap = replacement.overlaps(uae_to_replace.activity_execution)
        if overlap is not True: 
          # if log: logger.write(f'         x not overlaps {overlap}')
          continue

      if fallback_level < 3 and field_ids is not None:         
        if replacement.field.id not in field_ids:
          if log: logger.write(f'         x not on field {field_ids}, is {replacement.field.id}')
          continue

      replacement_uae = UnitActivityExecution(unit=scheduler.unit, activity_execution=replacement, headcount=uae_to_replace.headcount, score=uae_to_replace.score, phase=base_phase+fallback_level)
      assignability = scheduler.execution_rule_checker.is_assignable(replacement_uae)
      if assignability is not True:
        if log: logger.write(f'         x {assignability}')
        continue
      
      if log: logger.write(f'     +++ {replacement}')
      return replacement_uae

    # No replacement found
    if fallback_level < max_fallback_level:
      return self.replace_einheitsprogramm(scheduler, uae_to_replace, field_ids=field_ids, activity_ids=activity_ids, fallback_level=fallback_level + 1, max_fallback_level=max_fallback_level, log=log)
              
    scheduler.unit.assigned_activities.append(uae_to_replace)      
    uae_to_replace.activity_execution.assigned_units.append(uae_to_replace)
    return None

  def swap_unit_activity_executions(self, scheduler, missing=[252, 253]):
    still_missing = list(missing)
    hoarder_units = sorted(list(self.units), key=lambda unit: len([uae for uae in unit.assigned_activities if uae.activity_execution.activity_id in missing]), reverse=True)
    logger.write(f'\n\n* {scheduler.unit} misses {missing}')

    for uae in scheduler.unit.assigned_activities:
      if len(still_missing) <= 0:
          break

      if str(uae.phase) not in ['4', '9', '10', '11']: 
        continue

      if uae.activity_execution.activity.category not in ['einheitsprogramm']: 
        continue

      if uae.activity_execution.activity_id in missing:
        continue

      logger.write(f'  * {scheduler.unit} still misses {still_missing}, trying to swap {uae}')

      spot_id = next((spot_id for spot_id, field_ids in programmspots_fields.items() if uae.activity_execution.field.id in field_ids), None)
      found = False

      for hoarder_unit in hoarder_units:
        if found:
          break

        hoarded_count = len([uae for uae in hoarder_unit.assigned_activities if uae.activity_execution.activity_id in missing])
        if hoarded_count < 2:
          continue

        logger.write(f'    - {hoarder_unit} has {hoarded_count}')

        for possible_replacement_uae in hoarder_unit.assigned_activities:
          if possible_replacement_uae.activity_execution.activity_id not in still_missing: 
            continue

          if str(possible_replacement_uae.phase) not in ['4', '9', '10', '11']: 
            continue

          logger.write(f'      - trying to swap with {possible_replacement_uae}')

          overlap = uae.activity_execution.overlaps(possible_replacement_uae.activity_execution)
          if overlap is not True: 
            logger.write(f'        x no overlap {overlap}')
            continue

          replacement_spot_id = next((spot_id for spot_id, field_ids in programmspots_fields.items() if possible_replacement_uae.activity_execution.field.id in field_ids), None)
          if replacement_spot_id != spot_id:
            logger.write(f'        x {replacement_spot_id} not on spot {spot_id}')
            continue

          swap_candidate_1 = UnitActivityExecution(unit=scheduler.unit, activity_execution=possible_replacement_uae.activity_execution, headcount=uae.headcount, score=uae.score, phase="swap")
          scheduler.unit.assigned_activities.remove(uae)      
          uae.activity_execution.assigned_units.remove(uae)
          swap_candidate_2 = UnitActivityExecution(unit=hoarder_unit, activity_execution=uae.activity_execution, headcount=possible_replacement_uae.headcount, score=possible_replacement_uae.score, phase="swap")
          hoarder_unit.assigned_activities.remove(possible_replacement_uae)      
          possible_replacement_uae.activity_execution.assigned_units.remove(possible_replacement_uae)

          assignability_1 = scheduler.execution_rule_checker.is_assignable(swap_candidate_1)
          assignability_2 = self.unit_schedulers.get(hoarder_unit.id).execution_rule_checker.is_assignable(swap_candidate_1)

          if assignability_1 is True and assignability_2 is True:
            scheduler.unit.assigned_activities.append(swap_candidate_1)      
            swap_candidate_1.activity_execution.assigned_units.append(swap_candidate_1)
            hoarder_unit.assigned_activities.append(swap_candidate_2)      
            swap_candidate_2.activity_execution.assigned_units.append(swap_candidate_2)

            if possible_replacement_uae.activity_execution.activity_id in still_missing:
              still_missing.remove(possible_replacement_uae.activity_execution.activity_id) 
            logger.write(f'   +++ success')
            found = True
            break

          logger.write(f'        x  {assignability_1} {assignability_2}')

          scheduler.unit.assigned_activities.append(uae)      
          uae.activity_execution.assigned_units.append(uae)
          hoarder_unit.assigned_activities.append(possible_replacement_uae)      
          possible_replacement_uae.activity_execution.assigned_units.append(possible_replacement_uae)

    return still_missing
  
  
        # by_distance = sorted(einheitsprogramm_on_day, key=lambda uae: unit.district.calculate_distance(uae.activity_execution.field), reverse=True)
        # nearest = by_distance.pop()
        # distance = unit.district.calculate_distance(nearest.activity_execution.field)
        # logger.write(f'    {date}: {nearest} ({distance}) ')

      # for uae in scheduler.unit.assigned_activities:
      #   no_overlaps = scheduler.execution_rule_checker.rule_no_overlaps(uae)
      #   category = uae.activity_execution.activity.category
      
      #   if no_overlaps is not True:
      #     logger.write(f'     x {no_overlaps}')
      #     other_activity = no_overlaps.activity_2 if no_overlaps.activity_1.id == uae.activity_execution_id else no_overlaps.activity_1

      #     if category == 'einheitsprogramm' and other_activity.activity.category == 'activity':            
      #       logger.write(f'       Removing {uae}')
      #       uae.activity_execution.assigned_units.remove(uae)
      #       uae.unit.assigned_activities.remove(uae)
      #       scheduler.field_requirements.append(no_overlaps)

      #       best_replacement = None
      #       best_replacement_delta = None

      #       for replacement in self.einheitsprogramm_by_date[next(iter(uae.activity_execution.dates()))]:
      #         replacement_uae = UnitActivityExecution(unit= scheduler.unit, activity_execution=replacement, headcount=uae.headcount, score=uae.score, phase=9)
              
      #         if scheduler.execution_rule_checker.is_assignable(replacement_uae) is not True:
      #           continue
              
      #         replacement_delta = replacement.overlaps(other_activity)

      #         if best_replacement_delta is None or replacement_delta < best_replacement_delta:
      #           logger.write(f'         {replacement_delta} < {best_replacement_delta}')
      #           best_replacement = replacement_uae
      #           best_replacement_delta = replacement_delta
      #           logger.write(f'       + {replacement_uae}')

      #       if best_replacement is None:
      #         if no_overlaps.activity_ids() not in overlap_errors:
      #           overlap_errors.append(no_overlaps.activity_ids())
      #           self.errors.append(AssignmentError(unit=scheduler.unit, category=category, message=f'{no_overlaps}'))
      #       else:
      #         best_replacement.assign()
      #         scheduler.assigned_fields.append(best_replacement)
      #         logger.write(f'   +++ {best_replacement}')
  
      #     else:
      #       if category == 'activity' and other_activity.activity.category == 'einheitsprogramm':
      #         continue

      #       if no_overlaps.activity_ids() not in overlap_errors:
      #         logger.write(f'     x {no_overlaps}')
      #         overlap_errors.append(no_overlaps.activity_ids())
      #         self.errors.append(AssignmentError(unit=scheduler.unit, category=category, message=f'{no_overlaps}'))

  def remove_visitor_days_without_visitors(self):
    for id in no_visitor_day_units:
      scheduler = self.field_schedulers[id]
      logger.write(f' * {scheduler.unit}')
      day = None
      for uae in scheduler.unit.assigned_activities:
        if uae.activity_execution.activity_id != 223:
          continue

        uae.activity_execution.assigned_units.remove(uae)
        uae.unit.assigned_activities.remove(uae)
        day = next(iter(uae.activity_execution.dates()))
        break

      if day is not None:
        fixed = False
        for replacement in self.einheitsprogramm_by_date[next(iter(uae.activity_execution.dates()))]:
          replacement_uae = UnitActivityExecution(unit=scheduler.unit, activity_execution=replacement, score=0, phase=10)
              
          if scheduler.execution_rule_checker.is_assignable(replacement_uae) is not True:
            continue

          replacement_uae.assign()
          logger.write(f'     + {replacement}')
          fixed = True
          break

        if not fixed:
          self.errors.append(AssignmentError(unit=scheduler.unit, category="visitor_day", message=f'{day}'))


  def load_einheitsprogramm_by_date(self):
    activity_executions_by_date = {}

    for ae in self.activity_executions_by_id.values():
      if ae.activity.category != "einheitsprogramm": 
        continue

      date = next(iter(ae.dates()))

      if not date in activity_executions_by_date.keys():
        activity_executions_by_date[date] = [ae]
      else:
        activity_executions_by_date[date].append(ae)

    return activity_executions_by_date


  def einheitsprogramm_by_distance(self, to=None):
    cached = self.einheitsprogramm_by_distance_cache.get(to.cid, None)
    if cached is not None:
      return cached
    
    activity_executions_by_date_copy = {}
    for date, aes in self.einheitsprogramm_by_date.items():
      activity_executions_by_date_copy[date] = sorted(aes, key= lambda ae: (ae.field.calculate_distance(to)))

    self.einheitsprogramm_by_distance_cache[to.cid] = activity_executions_by_date_copy

    return activity_executions_by_date_copy
  
  def cluster_shuffle(array, cluster_size=10):
    result = []
    group = []
    for element in array:
      group.append(element)
      if len(group) >= cluster_size:
        random.shuffle(group)
        result.extend(group)
        group = []
    random.shuffle(group)
    result.extend(group)
    return result

  def schedule(self):
    self.load()

    try:
      if run_phase_1_visitor_day: self.phase_1_visitor_day()
      if run_phase_2_village_global_slot: self.phase_2_village_global_slot()
      if run_phase_3_wishlist: self.phase_3_wishlist()
      if run_phase_4_min_requirements: self.phase_4_min_requirements()
      if run_phase_5_pio_workshops: self.phase_5_pio_workshops()
      if run_phase_6_einheitsprogramm: self.phase_6_einheitsprogramm()
      if run_phase_7_showers: self.phase_7_showers()

      # self.phase_8_fix_pio_workshops()
      # self.rerun_activity_execution_checks()
      # self.remove_visitor_days_without_visitors()
      # self.reassign_einheitsprogramm_fields()
      self.fix_forbidden_fields_on_05_08()

      return self.recalculate_happyness()

    except TooManyFailuresError:
      return False

  def recalculate_happyness(self):
    happyness = 0
    pissedness = 0

    for scheduler in self.unit_schedulers.values():  
      happyness += scheduler.recalculate_happyness()
      pissedness += len(scheduler.unassigned_activities)

    for scheduler in self.field_schedulers.values():  
      happyness += int(scheduler.happyness() * 100)
      # pissedness += len(scheduler.unassigned_activities)

    self.score["happyness"] = happyness
    self.score["pissedness"] = pissedness
    return happyness

  def unit_to_csv(self):
    se_logger = Logger("missed_activities.csv")
    se_logger.write("Einheit;" + "Aktivität;" + "Kategorie;" + "Anzahl TN;"  + "Anzahl Leiter;" + "Sprache;" + "Stufe;" + "Wert bei Einheit;")
   
    wl_logger = Logger("wishlist.csv")
    wl_logger.write("Einheit;" + "Aktivität;" + "Kategorie;" + "Anzahl TN;"  + "Anzahl Leiter;" + "Sprache;" + "Stufe;" + "Wert bei Einheit;")

    u_logger = Logger("units.csv")
    u_logger.write("Einheit;" + "Sprache;" + "Stufe;" + "Anzahl TN;"  + "Anzahl Leiter;" + "von;" + "bis;")


    for unit_scheduler in self.unit_schedulers.values():
      tn = unit_scheduler.unit.participant_count
      leaders  = unit_scheduler.unit.leader_count
      u_logger.write(str(unit_scheduler.unit.id) + ";" + unit_scheduler.unit.language + ";" + unit_scheduler.unit.stufe + ";"  + str(tn) + ";" + str(leaders) + ";" + str(unit_scheduler.unit.starts_at) + ";" + str(unit_scheduler.unit.ends_at))
     
      for activity in unit_scheduler.unassigned_activities:
        score = unit_scheduler.activity_score(activity.id)
        se_logger.write(str(unit_scheduler.unit.id) + ";" + str(activity.id) + ";" + str(activity.category) + ";" + str(tn) + ";" + str(leaders) + ";" + unit_scheduler.unit.language + ";" + unit_scheduler.unit.stufe + ";" + str(score) + ";")
      for activity in unit_scheduler.unit.selected_activities.values():
        score = unit_scheduler.activity_score(activity.id)
        wl_logger.write(str(unit_scheduler.unit.id) + ";" + str(activity.id) + ";" + str(activity.category) + ";" + str(tn) + ";" + str(leaders) +";" + unit_scheduler.unit.language + ";" + unit_scheduler.unit.stufe + ";" + str(score) + ";")

    se_logger.flush()
    wl_logger.flush()
    u_logger.flush()

  def unit_activity_executions_to_csv(self):
    uae_logger = Logger("scheduled_unit_activity_executions.csv")
    uae_logger.write(";".join(["Einheit", "Aktivitätsdurchführung", "Aktivität", "Kategorie", "Start", "Ende", "Spot", "Feld", "Personen", "Sprache", "Stufe", "aus Phase", "Wert bei Einheit", "Abteilung"]))

    ae_logger = Logger("scheduled_activity_executions.csv")
    ae_logger.write(";".join(["Aktivitätsdurchführung", "Aktivität", "Kategorie", "Stufen", "Sprache", "Start",  "Ende", "Spot", "Feld", "Kapazität", "Verplant", "Auslastung", "Datum", "Einheiten"]))

    for activity_execution in self.activity_executions_by_id.values():
      activity = self.activities[activity_execution.activity_id]
      ae_logger.write(";".join([str(activity_execution.id),
                                str(activity_execution.activity_id),
                                activity.category,
                                ",".join(activity.stufen),
                                ",".join(activity_execution.languages),
                                activity_execution.starts_at,
                                activity_execution.ends_at,
                                str(activity_execution.spot.get("name")),
                                f'{activity_execution.field.cid}: {activity_execution.field.text}',
                                str(activity_execution.amount_participants),
                                str(activity_execution.headcount_used()),
                                str(activity_execution.percentage_used()),
                                activity_execution.starts_at.split("T")[0],
                                str(len(activity_execution.assigned_units))]))

      for uae in activity_execution.assigned_units:
        uae_logger.write(";".join([str(uae.unit_id),
                                   str(uae.activity_execution_id),
                                   str(uae.activity_id),
                                   str(activity.category),
                                   uae.activity_execution.starts_at,
                                   uae.activity_execution.ends_at,
                                    str(activity_execution.spot.get("name")),
                                    str(activity_execution.field),
                                   str(uae.headcount), uae.unit.language,
                                   uae.unit.stufe,
                                   str(uae.phase),
                                   str(uae.score),
                                   uae.unit.abteilung]))

    uae_logger.flush()
    ae_logger.flush()

  def transport_unit_assignments_to_csv(self):
    tua_logger = Logger("transport_unit_assignments.csv")
    tua_logger.write("Transport_Id;" + "Transport_Capacity;" + "Assigned_Unit;" + "Assigned_Unit_Capacity")

    for transport in self.transports.values():
      output = str(transport.id) + "; " + str(transport.capacity) + ";"

      for unit in transport.assigned_units:
        tua_logger.write(output + str(unit.id) + ";" + str(unit.size()))
      
    tua_logger.flush()

  def scheduling_errors_to_csv(self):
    err_logger = Logger("scheduling_errors.csv")
    err_logger.write("Einheit;" + "Stufe;" + "Woche;" + "Sprache;" + "Anzahl TN;" + "Anzahl Leiter;" + "Problemkategorie;" + "Problem bei der Zuteilung;")

    for error in self.errors:
      err_logger.write(str(error.unit.id) + ";" + str(error.unit.stufe) + ";" + str(error.unit.week) + ";" + str(error.unit.language) + ";" + str(error.unit.participant_count) + ";" + str(error.unit.leader_count) + ";" + error.category + ";" + str(error.message))
      
    err_logger.flush()

  def to_csv(self):
    self.unit_to_csv()
    self.unit_activity_executions_to_csv()
    self.transport_unit_assignments_to_csv()
    self.scheduling_errors_to_csv()

# %% [markdown]
# # SchedulerPicker

# %%
class SchedulePicker:
  def __init__(self, loader):
    self.loader = loader
 
  def run(self, iterations=10):
    highscore = 0
    min_errors = None
    best = None

    for i in range(iterations):
      current = MovaScheduler(self.loader)
      logger.set_file("assignment_current.log")
      score = current.schedule()
      logger.write(current)
      logger.file.close
      if score is False:
        print("x")
        continue

      errors = len(current.errors)
      print(current)
      print()
      # if min_errors is None or errors < min_errors or (errors == min_errors and score > highscore):

      if highscore is None or score > highscore:
        best = current
        min_errors = errors
        highscore = score
        os.rename('assignment_current.log', 'assignment_best.log')
      
    print(best)
    best.to_csv()
    print("Done")

# %% [markdown]
# # UnitScheduler

# %%
class UnitScheduler:
  def __init__(self, unit, mova_scheduler):
    self.unit = unit
    self.mova_scheduler = mova_scheduler
    self.happyness = self.recalculate_happyness()
    self.happyness = 0
    self.unassigned_activities = []
    self.wishlist = sorted(unit.selected_activities.values(), key=lambda selected_activity: selected_activity.priority)
    self.village_global_scheduler = None
    self.unitfieldScheduler = None
    self.activity_rule_checker = UnitActivityRuleChecker(self)
    self.execution_rule_checker = UnitActivityExecutionRuleChecker(self.mova_scheduler)

  def group_unit_activity_executions_by_category(self):
    grouped = {}
    for uae in self.unit.assigned_activities:
      category = self.mova_scheduler.activities[uae.activity_id].category
      if category in grouped: grouped[category].append(uae)
      else: grouped[category] = [uae]
    return grouped

  def count_unit_activity_executions_by_category(self):
    return { category: len(uaes) for category, uaes in self.group_unit_activity_executions_by_category().items() }

  def assigned_activity_ids(self):
    return [uae.activity_id for uae in self.unit.assigned_activities]

  def excursions_count(self):
    groups = self.group_unit_activity_executions_by_category()
    return len(groups.get("excursion", [])) + len(groups.get("culture", [])) + len(groups.get("sport", [])) + len(groups.get("water", []))

  def mova_activity_count(self):
    return self.count_unit_activity_executions_by_category().get('activity', 0)

  def hikings_count(self):
    groups = self.group_unit_activity_executions_by_category()
    count = len(groups.get("hiking", []))
    for uae in groups.get("hiking", []): 
      if uae.activity_id in two_day_hikes: # See https://bulacafe21.slack.com/archives/D014ZABVCCA/p1636878399000100
        count += 1

    return count

  def __repr__(self):
    return str(self.unit) + "  😀 " + str(self.happyness) + "  😡 " + str(len(self.unassigned_activities))

  def activity_score(self, activity_id):
    activity = self.unit.selected_activities.get(activity_id)
    if activity is None:
      return 0
    return max(25 - activity.priority, 1)

  def recalculate_happyness(self):
    happyness = 0
    for uae in self.unit.assigned_activities:
      happyness += self.activity_score(uae.activity_id)

    return happyness
  
  def wishlist_assignment(self):
    for item in self.wishlist:
      logger.write(" (*) " + str(item))

    while len(self.wishlist) > 0:
      activity = self.wishlist.pop(0)  
      score = self.activity_score(activity.id)
      logger.write(" * " + str(activity))

      activity_assignable = self.activity_rule_checker.is_assignable(activity)
      if activity_assignable is True:
        if activity.category == "village_global":  
          # Village Global should be assigned at this point already
          continue

        else:
          executions = self.mova_scheduler.activity_executions_by_activity_id[activity.id] or []
          random.shuffle(executions)

          if activity.id in [172, 173, 174, 175]:
            logger.write("   ^ order: most free first ")
            executions = sorted(executions, key=lambda execution: execution.headcount_free(), reverse=True)
          elif activity.id in []: 
            logger.write("   ^ order: nearest first ")
            # TODO: which activities are sorted by distance?
            executions = sorted(executions, key=lambda execution: execution.get_distance(self.unit.district))
          else:
            logger.write("   ^ order: most used first ")
            executions = sorted(executions, key=lambda execution: execution.headcount_free())
            executions = MovaScheduler.cluster_shuffle(executions)

          for execution in executions:
            logger.write("   * " + str(execution))
            uae = UnitActivityExecution(unit=self.unit, activity_execution=execution, phase=1, score=score)
            execution_assignable = self.execution_rule_checker.is_assignable(uae)
            if execution_assignable is True:
              logger.write("     +  Assigned " + str(uae))
              uae.assign()
              if execution.has_transport(): 
                transports = self.mova_scheduler.get_transport(execution.transport_ids)
                for transport in transports: 
                  transport.assign_unit(self.unit)

              self.happyness += score 
              return True 
            else:
              logger.write("      x " + execution_assignable)

          self.unassigned_activities.append(activity)
          logger.write("   - Assignment for activity " + str(activity.id) + " and unit " + str(self.unit.id) + " not possible")

      else:
        logger.write("    x :" + activity_assignable)

    
    logger.write(" : Unit " + str(self.unit.id) + " has no further bookings to schedule")
    return False

  def village_global_assignment(self):
    if self.count_unit_activity_executions_by_category().get('village_global', 0) <= 0:
      self.village_global_scheduler = VillageGlobalScheduler(self)
      uaes = self.village_global_scheduler.find_best_slot()
      if uaes == False or uaes is None:
        logger.write(" - cannot fullfill village global requirements")
        return False
      else:
        for uae in uaes:
          logger.write("  ** Assigned " + str(uae))
          uae.activity_execution.stufen = [self.unit.stufe]
          uae.assign()
    
    logger.write(" + village global requirements should be ok")
    return True
      
  def missing_activity_assignments(self, phase=4):
    for try_no in range(100):
      needs = self.activity_rule_checker.needs_more_of(phase)
      if needs is False:
        logger.write(" : " + str(self.unit) + " is all clear")
        return True

      need = list(needs.keys())[0]
      if len(needs[need]) <= 0:
        return need
      assignments = self.missing_activity_assignment(needs[need])
      if assignments is not True:
        return str(needs)
    return "Took more than 100 tries"
    
  def missing_activity_assignment(self, needs):
    random.shuffle(needs)
    for needed_activity in needs:
      logger.write(" * " + str(needed_activity))
      activity_assignable = self.activity_rule_checker.is_assignable(needed_activity)
      if activity_assignable is not True:
        logger.write("   x :" + activity_assignable)
        continue

      for execution in sorted(self.mova_scheduler.activity_executions_by_activity_id[needed_activity.id], key=lambda ae: ae.headcount_free()):
        logger.write("   * " + str(execution))
        uae = UnitActivityExecution(unit=self.unit, activity_execution=execution, phase=3)
        assignable = self.execution_rule_checker.is_assignable(uae)
        if assignable is True:
          logger.write("     + Assigned " + str(uae))
          uae.assign()
          if execution.has_transport(): 
            for transport in self.mova_scheduler.get_transport(execution.transport_ids): 
              transport.assign_unit(self.unit)
          return True
        else:
          logger.write("     x :" + assignable)

    logger.write(" Needs could not be fullfilled: " + str(needs))
    return needs

# %% [markdown]
# # Scheduling

# %%
#@title Parameter für Scheduler
max_units =  1000#@param {type:"integer"}
iterations =  10#@param {type:"integer"}
output = False #@param {type:"boolean"}
failures_threshold =  40#@param {type:"integer"}
run_phase_1_visitor_day = False #@param {type:"boolean"}
run_phase_2_village_global_slot = False #@param {type:"boolean"}
run_phase_3_wishlist = False #@param {type:"boolean"}
run_phase_4_min_requirements = False #@param {type:"boolean"}
run_phase_6_einheitsprogramm = False #@param {type:"boolean"}
run_sideload = True #@param {type:"boolean"}
run_phase_5_pio_workshops = False #@param {type:"boolean"}
run_phase_7_showers = False #@param {type:"boolean"}
max_fallback_level =  4#@param {type:"integer"}
headers = {'Cookie': '_orca_session=' }
loader = OrcaLoader(headers, max_units)
logger = Logger("assignment.log", output=output)
SchedulePicker(loader).run(iterations)
logger.flush()
